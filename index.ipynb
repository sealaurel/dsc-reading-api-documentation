# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
keys = get_keys("/Users/elena/Documents/Flatiron/Supplemental/.secret/yelp_api_info.json")

api_key = keys['api_key']
print(api_key)

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!
# Out:
# dRYeS-zqsiJfz1e8hvmNqcgeWp700y_AgjJbM8M5y6d-nkbNP9uEw2nysh-nZoZbABWCr0flFrFL-kjrN9_z-zG1SiTqT0OJIKskgf5e8CNU5hacM53e7DwC1IRJYHYx

# %%
import requests

# %%
url = 'https://api.yelp.com/v3/businesses/search'     #This will be our next step
headers = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, headers=headers)

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
import pandas as pd
df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df))
print(df.columns)
df.head(10)
# Out:
# 50
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance'],
#       dtype='object')
#                        id                                              alias  \
# 0  oOr6Ta5gZyDl6PyZ1cq7pg                        east-village-pizza-new-york
# 1  uc5qQMzs96rzjK27epDCug                              joes-pizza-new-york-4
# 2  oJ_XSPZFpvIt6rvheSQl7A                     bleecker-street-pizza-new-york
# 3  0UdC0VYX6aAvLiOcpR4MVQ                              joes-pizza-new-york-7
# 4  4h4Tuuc56YPO6lWfZ1bdSQ                            joes-pizza-new-york-152
# 5  vpkTNjq9dRh9rT3Nh0pe-A                            nolita-pizza-new-york-2
# 6  MwcRbM6lS6_8N67LmyBELA                     99-cent-fresh-pizza-new-york-5
# 7  vfYhEpp0x-DrNjC6GSJjPQ                artichoke-basilles-pizza-new-york-2
# 8  A46G2OAvLxFswiONB50Rrg                             koronet-pizza-new-york
# 9  i9UMc9gLeORtCLd-OoGgYg  lions-and-tigers-and-squares-detroit-pizza-new...
#
#                                      name  \
# 0                      East Village Pizza
# 1                             Joe's Pizza
# 2                   Bleecker Street Pizza
# 3                             Joe's Pizza
# 4                             Joe's Pizza
# 5                            Nolita Pizza
# 6                     99 Cent Fresh Pizza
# 7               Artichoke Basille's Pizza
# 8                           Koronet Pizza
# 9  Lions & Tigers & Squares Detroit Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/xlYeMx...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/BTCcvl...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/yo5oXK...      False
# 5  https://s3-media4.fl.yelpcdn.com/bphoto/HGcUMC...      False
# 6  https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIh...      False
# 7  https://s3-media3.fl.yelpcdn.com/bphoto/4krjwP...      False
# 8  https://s3-media3.fl.yelpcdn.com/bphoto/RfL3dl...      False
# 9  https://s3-media4.fl.yelpcdn.com/bphoto/mR_LiC...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/east-village-pizza-ne...           329
# 1  https://www.yelp.com/biz/joes-pizza-new-york-4...          2600
# 2  https://www.yelp.com/biz/bleecker-street-pizza...          2385
# 3  https://www.yelp.com/biz/joes-pizza-new-york-7...           918
# 4  https://www.yelp.com/biz/joes-pizza-new-york-1...           219
# 5  https://www.yelp.com/biz/nolita-pizza-new-york...            57
# 6  https://www.yelp.com/biz/99-cent-fresh-pizza-n...           541
# 7  https://www.yelp.com/biz/artichoke-basilles-pi...          3978
# 8  https://www.yelp.com/biz/koronet-pizza-new-yor...           634
# 9  https://www.yelp.com/biz/lions-and-tigers-and-...           467
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 5  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 6             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 7             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 8             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 9             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 40.728199, 'longitude': -73.985182}  [pickup, delivery]
# 1  {'latitude': 40.73060076, 'longitude': -74.002...          [delivery]
# 2  {'latitude': 40.7320627016512, 'longitude': -7...  [pickup, delivery]
# 3     {'latitude': 40.73331, 'longitude': -73.98763}  [pickup, delivery]
# 4  {'latitude': 40.7101297729083, 'longitude': -7...  [pickup, delivery]
# 5  {'latitude': 40.7208883, 'longitude': -73.9962...  [pickup, delivery]
# 6     {'latitude': 40.76458, 'longitude': -73.98247}  [pickup, delivery]
# 7  {'latitude': 40.7321124557704, 'longitude': -7...  [pickup, delivery]
# 8     {'latitude': 40.80447, 'longitude': -73.96616}  [pickup, delivery]
# 9     {'latitude': 40.74506, 'longitude': -73.99834}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '145 1st Ave', 'address2': '', 'a...  +12125294545
# 1     $  {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
# 2     $  {'address1': '69 7th Ave S', 'address2': None,...  +12129244466
# 3     $  {'address1': '150 E 14th St', 'address2': '', ...  +12123889474
# 4     $  {'address1': '124 Fulton St', 'address2': '', ...  +12122670860
# 5     $  {'address1': '68 Kenmare St', 'address2': None...  +16468959131
# 6     $  {'address1': '1723 Broadway', 'address2': '', ...  +12122452155
# 7     $  {'address1': '321 E 14th St', 'address2': '', ...  +12122282004
# 8     $  {'address1': '2848 Broadway', 'address2': '', ...  +12122221566
# 9     $  {'address1': '268 W 23rd St', 'address2': '', ...  +19172616772
#
#     display_phone      distance
# 0  (212) 529-4545   2643.857504
# 1  (212) 366-1182   2874.702514
# 2  (212) 924-4466   3073.574220
# 3  (212) 388-9474   3133.913077
# 4  (212) 267-0860   1245.942863
# 5  (646) 895-9131   1725.054309
# 6  (212) 245-2155   6652.683138
# 7  (212) 228-2004   3091.822114
# 8  (212) 222-1566  11258.427546
# 9  (917) 261-6772   4417.875679

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
